# %% [markdown]
# #Linear Algebra Basics

# %% [markdown]
# ## Sheriff and Bank Robber

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0, 40, 1000) # start, finish, n points

# %% [markdown]
# Distance traveleb by the robber: d = 2.5t

# %%
d_r = 2.5 * t

# %%
d_s = 3*(t-5)

# %%
fig, ax = plt.subplots()
plt.title("Bank robber caught")
plt.xlabel('time min')
plt.ylabel('distance km')
ax.set_xlim([0,40])
ax.set_ylim([0,100])
ax.plot(t,d_r,c='green')
ax.plot(t,d_s,c='brown')
plt.axvline(x=30,color='purple',linestyle='--')
_ = plt.axhline(y=75, color ='purple', linestyle='--')

# %% [markdown]
# ## Scalars

# %%
x=25
x
# Out:
# 25

# %%
type(x)
# Out:
# int

# %%
y =23
py_sum = x+y
py_sum
# Out:
# 48

# %%
x_float = 2.4
py_sum += x_float
type(py_sum)
# Out:
# float

# %% [markdown]
# ### Pytorch

# %%
import torch

# %%
x_pt = torch.tensor(25)
x_pt
# Out:
# tensor(25)

# %%
x_pt.shape
# Out:
# torch.Size([])

# %% [markdown]
# ### Tensorflow

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable(25, dtype =tf.int16)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=25>

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
y_tf = tf.Variable(3,dtype=tf.int16)

# %%
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=28>

# %%
sum_tf = tf.add(x_tf,y_tf)
sum_tf
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=28>

# %%
sum_tf.numpy() #  converte tensor pra numpy arrays e vice versa
# Out:
# np.int16(28)

# %%
type(sum_tf.numpy())
# Out:
# numpy.int16

# %%
tf_float = tf.Variable(25, dtype=tf.float64)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float64, numpy=25.0>

# %% [markdown]
# # Vectors

# %%
import numpy as np

# %%
x = np.array([25,2,5])
x, len(x)
# Out:
# (array([25,  2,  5]), 3)

# %%
x.shape, type(x)
# Out:
# ((3,), numpy.ndarray)

# %%
type(x[0])
# Out:
# numpy.int64

# %% [markdown]
# ### Vector Transposition

# %%
x_t = x.T
x_t, x_t.shape
#transposing it has no effect because it's 2D
# Out:
# (array([25,  2,  5]), (3,))

# %%
y = np.array([[25,2,5]])
y, y.shape
# Out:
# (array([[25,  2,  5]]), (1, 3))

# %%
y_t = y.T
y_t
# Out:
# array([[25],
#        [ 2],
#        [ 5]])

# %%
y_t.shape
# Out:
# (3, 1)

# %% [markdown]
# ### Zero Vector

# %%
z = np.zeros(3)
z
# Out:
# array([0., 0., 0.])

# %% [markdown]
# ## Pytorch and Tensorflow

# %%
x_pt = torch.tensor([24,2,5])
x_pt
# Out:
# tensor([24,  2,  5])

# %%
x_tf = tf.Variable([25,2,5])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([25,  2,  5], dtype=int32)>

# %% [markdown]
# ## L² Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
(25**2 + 2**2 + 5**2) ** (1/2)
# Out:
# 25.573423705088842

# %%
np.linalg.norm(x)
# Out:
# np.float64(25.573423705088842)

# %% [markdown]
# ## L¹ Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
np.abs(25)+ np.abs(2) +np.abs(5)
# Out:
# np.int64(32)

# %% [markdown]
# ## Squared L2 Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
(25**2 + 2**2 + 5**2)
# Out:
# 654

# %%
np.dot(x,x)
# Out:
# np.int64(654)

# %% [markdown]
# ## Max Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
np.max([np.abs(25),np.abs(2),np.abs(5)])
# Out:
# np.int64(25)

# %% [markdown]
# ## Orthogonal Vectors

# %%
i = np.array([1,0])
j = np.array([0,1])

# %%
np.dot(i,j)
# Out:
# np.int64(0)

# %% [markdown]
# # Matrix Tensors

# %% [markdown]
# ### Numpy

# %%
X = np.array([[25,2], [5,26],[3,7]])
X
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
X.shape, X.size
# Out:
# ((3, 2), 6)

# %%
X[:,0] #coluna esquerda
# Out:
# array([25,  5,  3])

# %%
X[1,:] # linha do meio
# Out:
# array([ 5, 26])

# %%
X[0:2,0:2] #slicing
# Out:
# array([[25,  2],
#        [ 5, 26]])

# %% [markdown]
# ### PyTorch

# %%
X_pt = torch.tensor([[25,2], [5,26],[3,7]])
X_pt
# Out:
# tensor([[25,  2],
#         [ 5, 26],
#         [ 3,  7]])

# %%
X_pt.shape
# Out:
# torch.Size([3, 2])

# %%
X_pt[1,:]
# Out:
# tensor([ 5, 26])

# %% [markdown]
# ### Tensorflow

# %%
X_tf = tf.Variable([[25,2], [5,26],[3,7]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]], dtype=int32)>

# %%
tf.rank(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %%
tf.shape(X_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([3, 2], dtype=int32)>

# %%
X_tf[1,:]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([ 5, 26], dtype=int32)>

# %% [markdown]
# # Tensors

# %% [markdown]
# rank 4 tensors are common for images.
# 1. number of images in batch
#
# 2. image height in pixels
#
# 3. image width in px
#
# 4. number of color channels, e.g., 3 for full color (RGB)

# %%
images_pt = torch.zeros([32,28,28,3])
images_pt

# %%
images_tf = tf.zeros([32,28,28,3])
images_tf
