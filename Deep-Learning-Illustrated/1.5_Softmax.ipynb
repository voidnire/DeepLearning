# %%
from math import exp

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
z = [-1.0, 1.0, 5.0]

# %%
exp(z[0]), exp(z[1]), exp(z[2])#hot dog, burger & pizza
# Out:
# (0.36787944117144233, 2.718281828459045, 148.4131591025766)

# %%
total = exp(z[0]) + exp(z[1]) + exp(z[2])
total
# Out:
# 151.49932037220708

# %%
exp(z[0])/total # chance de ser hotdog 0,2
# Out:
# 0.0024282580295913376

# %%
exp(z[1])/total # chance de ser burger 1,8
# Out:
# 0.017942534803329194

# %%
exp(z[2])/total # chance de ser pizza 98
# Out:
# 0.9796292071670795
