# %% [markdown]
# ## Tensor Transposition

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import tensorflow as tf

# %%
X_tf = tf.Variable([[25,2], [5,26],[3,7]])
X = np.array([[25,2], [5,26],[3,7]])
X_pt = torch.tensor([[25,2], [5,26],[3,7]])
X
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
X.T
# Out:
# array([[25,  5,  3],
#        [ 2, 26,  7]])

# %%
tf.transpose(X_tf)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[25,  5,  3],
#        [ 2, 26,  7]], dtype=int32)>

# %%
X_pt.T
# Out:
# tensor([[25,  5,  3],
#         [ 2, 26,  7]])

# %% [markdown]
# ## Basic Tensor Arithmetic

# %% [markdown]
# adding and multiplying with scalar = applies to all elements

# %%
X*2
# Out:
# array([[50,  4],
#        [10, 52],
#        [ 6, 14]])

# %%
X+2
# Out:
# array([[27,  4],
#        [ 7, 28],
#        [ 5,  9]])

# %%
X*2+2
# Out:
# array([[52,  6],
#        [12, 54],
#        [ 8, 16]])

# %%
X_pt*2+2
# Out:
# tensor([[52,  6],
#         [12, 54],
#         [ 8, 16]])

# %%
X_tf*2+2 # python operators are overloaded, best to use torch.mul() .add()
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[52,  6],
#        [12, 54],
#        [ 8, 16]], dtype=int32)>

# %%
torch.add(torch.mul(X_pt,2),2)
# Out:
# tensor([[52,  6],
#         [12, 54],
#         [ 8, 16]])

# %% [markdown]
# > Hadarmard Product or Element-wise product
#
# A ⊙ X

# %%
X
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
A = X+2

# %%
A+X
# Out:
# array([[52,  6],
#        [12, 54],
#        [ 8, 16]])

# %%
A*X
# Out:
# array([[675,   8],
#        [ 35, 728],
#        [ 15,  63]])

# %% [markdown]
# ## Reduction

# %% [markdown]
# soma entre todos elementos

# %%
X.sum()
# Out:
# np.int64(68)

# %%
torch.sum(X_pt)
# Out:
# tensor(68)

# %%
tf.reduce_sum(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=68>

# %%
# pode fazer com 1 só axis
X.sum(axis=0)
# Out:
# array([33, 35])

# %%
X.sum(axis=1)
# Out:
# array([27, 31, 10])

# %%
torch.sum(X_pt,0)
# Out:
# tensor([33, 35])

# %%
tf.reduce_sum(X_tf,1)
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([27, 31, 10], dtype=int32)>

# %% [markdown]
# max, min, mean, product podem ser applied com reduction

# %% [markdown]
# ## Dot Product

# %% [markdown]
# dois vetores da mesma altura, calcula o dot product.
#  performado muito em neuronios de neural network

# %% [markdown]
# ![imagem_2026-01-10_170032324.png](data:image/png;base64,...)

# %%
x = np.array([25,2,5])
y = np.array([0,1,2])

# %%
25*0 + 2*1 + 5*2
# Out:
# 12

# %%
np.dot(x,y)
# Out:
# np.int64(12)

# %%
np.dot(x,y)
# Out:
# np.int64(12)

# %%
torch.dot(torch.tensor([25,2,5.]),torch.tensor([0,1,2.]))
# Out:
# tensor(12.)

# %%
y_tf = tf.Variable([0,1,2])
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([0, 1, 2], dtype=int32)>

# %%
x_tf = tf.Variable([25,2,5])
tf.reduce_sum(tf.multiply(x_tf,y_tf))
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=12>

# %% [markdown]
# ## Solving Linear Systems

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = np.linspace(-10, 10, 1000) # start, finish, n points

# %%
y1 = 3 * x
y2 = 1 + (5*x)/2

# %%
fig, ax = plt.subplots()
plt.xlabel('x')
plt.ylabel('y')
ax.set_xlim([0, 3])
ax.set_ylim([0, 8])
ax.plot(x, y1, c='green')
ax.plot(x, y2, c='brown')
plt.axvline(x=2, color='purple', linestyle='--')
_ = plt.axhline(y=6, color='purple', linestyle='--')
